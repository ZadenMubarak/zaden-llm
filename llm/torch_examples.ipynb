# %%
import torch
import numpy as np
import time

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')
# Out:
# Using device: cpu

# %%
start_time = time.time()
zeros = torch.zeros(1,1)
end_time = time.time()
elapsed_time = end_time - start_time
print(f'Time taken to create a tensor: {elapsed_time:.10f} seconds')
# Out:
# Time taken to create a tensor: 0.0003101826 seconds
